# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
data_frame = pd.read_csv('data/train.csv')

# %%
data_frame
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # 데이터 프레임은 2차원 배열이다.
# # pandas는 numpy를 사용함.
# # 데이터프레임은 시리즈의 결합체이다.

# %%
data_frame.tail(2)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1458         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [2 rows x 81 columns]

# %%
type(data_frame.Id) # 각각의 colume은 시리즈다.
# Out:
# pandas.core.series.Series

# %%
# 시리즈은 list를 사용한다.
s1 = pd.core.series.Series([1,2,3])
s2 = pd.core.series.Series(['one','two','three'])

# %%
pd.DataFrame(data=dict(숫자임=s1, 글자한글=s2))
# Out:
#    숫자임   글자한글
# 0    1    one
# 1    2    two
# 2    3  three

# %%
# !conda list | grep pandas
# Out:
# /bin/bash: line 1: conda: command not found

# %%
conda list | grep pandas
# Out:
# pandas                    1.1.3            py38he6710b0_0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("data/train.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail(3)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [3 rows x 81 columns]

# %%
 # 만약에 tab으로 구분해야 할 경우에 이렇게 해야함.
df = pd.read_csv('data/train.csv', delimiter='\t')

# %%
# 헤더가 없을 경우
df = pd.read_csv('data/train.csv', header = None)

# %%
# 헤더를 설정해주는 법
df.columns = ['name', 'age', 'job']


## 이 모든걸 한번에
df = pd.read_csv('data/train.csv', header=None, names=['name', 'age','job'])

# %%
friend_dict_list = [
    {"name":"john", 'age': 25, 'job':'student'},
    {"name": "nate", 'age':30, 'job': 'teacher'}
]
df = pd.DataFrame(friend_dict_list)

# %%
df.head()
# Out:
#    name  age      job
# 0  john   25  student
# 1  nate   30  teacher

# %%
df = df[['name', 'age', 'job']]

# %%
df.head()
# Out:
#    name  age      job
# 0  john   25  student
# 1  nate   30  teacher

# %%
from collections import OrderedDict
# 키의 순서를 보장함. 딕셔너리는 colume의 순서를 보장하지 못한다.
friend_ordered_dict = OrderedDict(
    [
        ('name', ['John', 'Nate']),
        ('age',[25,30]),
        ('job',['student', 'teacher'])
    ]
)

df = pd.DataFrame.from_dict(friend_ordered_dict)

# %%
df.head()
# Out:
#    name  age      job
# 0  John   25  student
# 1  Nate   30  teacher

# %%
friend_list = [
    ['John', 20, 'student'],
    ['Nate', 30, 'Teacher']
]

column_name = ['name', 'age', 'job']

# %%
df = pd.DataFrame.from_records(friend_list, columns=column_name)

# %%
df.head()
# Out:
#    name  age      job
# 0  John   20  student
# 1  Nate   30  Teacher

# %%
friend_list = [
    ['name',['john', 'nate']],
    ['age',[20, 30]],
    ['job',['student', 'teacher']]
]

# %%
df = pd.DataFrame.from_items(friend_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-678971fcd1fb> in <module>
# ----> 1 df = pd.DataFrame.from_items(friend_list)
#
# AttributeError: type object 'DataFrame' has no attribute 'from_items'
